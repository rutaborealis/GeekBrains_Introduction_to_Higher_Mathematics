# %%
# Lesson 3
# Task 10.1
import numpy
import matplotlib.pyplot as plot
from scipy.optimize import fsolve

def equations(p):
    x, y = p
    # print(x)
    # print(y)
    return (x ** 2 - 1 - y, numpy.exp(x) + x * (2 - x ** 2) - 1)

x = numpy.linspace(-2, 3, 500)

# print(equations([-1, 1]))
x1, y1 = fsolve(equations, (-10, 10))             
print (x1, y1)

plot.figure(figsize = (10, 10))
plot.plot(x, numpy.exp(x) + x * (2 - x ** 2) - 1, color='blue')
plot.plot(x, x ** 2 - 1, color='red')
plot.xlabel('x')
plot.ylabel('y')
plot.grid(True)
plot.ylim(-2, 8)
# Out:
# -1.5818353528958495 1.5022030836711509
# (-2.0, 8.0)

# %%
# Lesson 3
# Task 10.2
import numpy
import matplotlib.pyplot as plot
from scipy.optimize import fsolve

def equations(p):
    x, y = p
    # print(x)
    # print(y)
    return (x ** 2 - 1 - y, numpy.exp(x) + x * (2 - x ** 2) - 1)

x = numpy.linspace(-2, 3, 500)

plot.figure(figsize = (10, 10))
plot.plot(x, numpy.exp(x) + x * (2 - x ** 2) - 1, color='blue')
plot.plot(x, x ** 2 - 1, color='red')
plot.xlabel('x')
plot.ylabel('y')
plot.grid(True)
plot.ylim(-2, 8) 

# print(equations([-1, 1]))
x1, y1 = fsolve(equations, (-1, 1))             
print (x1, y1)
# Out:
# -1.581835352895898 1.5022030836712905

# %%
import numpy
import matplotlib.pyplot as plot
from scipy.optimize import fsolve

def equations(p):
    x, y = p
    # print(x)
    # print(y)
    return(x ** 2 - 1 - y, (numpy.exp(x) - 1) / x + 1 - y)

x = numpy.linspace(-2, 3, 500)

plot.figure(figsize = (10, 10))
plot.plot(x, (numpy.exp(x) - 1) / x + 1, color='blue')
plot.plot(x, x ** 2 - 1, color='red')
plot.xlabel('x')
plot.ylabel('y')
plot.grid(True)
plot.ylim(-2, 8) 

# print(equations([-1, 1]))
x1, y1 = fsolve(equations, (-1, 1))
              
# print (x1, y1)

# %%
import numpy
import matplotlib.pyplot as plot
from scipy.optimize import fsolve

def f(x):
    return (numpy.sin(x + 1))

x = numpy.linspace(-3 * numpy.pi, 3 * numpy.pi, 500)

x0 =  fsolve(f, 1)
print (x0)

plot.figure(figsize = (10, 10))
plot.plot(x, f(x), color='blue')
plot.plot([-10, 10], [0,0], color='red', alpha=0.5)
plot.grid(True)
plot.xlabel('x')
plot.ylabel('y')
# Out:
# [2.14159265]
# Text(0, 0.5, 'y')

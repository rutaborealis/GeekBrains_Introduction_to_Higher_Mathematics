# %%
import numpy
import matplotlib.pyplot as plot

fig = plot.figure(figsize = (10, 10))

x = numpy.linspace(0, 10, 1000)
k1 = 1
k2 = 20

plot.plot(x, np.cos(k1 * x), color='red')
plot.plot(x, np.cos(k2 * x), color='blue', alpha=0.25)
